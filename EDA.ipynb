# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandasql import sqldf

# %%
df1=pd.read_csv('E:/NewDrive/DataScienceProjects/DataSets/Flipkart_dataset/VivoCleaned.csv')
df2=pd.read_csv('E:/NewDrive/DataScienceProjects/DataSets/Flipkart_dataset/SamsungCleaned.csv')
df3=pd.read_csv('E:/NewDrive/DataScienceProjects/DataSets/Flipkart_dataset/AppleCleaned.csv')
df4=pd.read_csv('E:/NewDrive/DataScienceProjects/DataSets/Flipkart_dataset/MiCleaned.csv')
df5=pd.read_csv('E:/NewDrive/DataScienceProjects/DataSets/Flipkart_dataset/REALMECleaned.csv')
df6=pd.read_csv('E:/NewDrive/DataScienceProjects/DataSets/Flipkart_dataset/POCOCleaned.csv')

# %%
df_Mod=pd.concat([df1,df2,df3,df4,df5,df6])

# %%
df.rename(columns = {'Sales(₹ CR)':'Sales'}, inplace = True)
df.rename(columns = {'No of Rear Camera':'NoOfFrontCAM'}, inplace = True)
df.rename(columns = {'No of Front Camera':'NoOfRearCAM'}, inplace = True)
df.rename(columns = {'Battery(mAh':'Battery'}, inplace = True)

# %%
df.to_csv('E:/NewDrive/DataScienceProjects/DataSets/Flipkart_dataset/Model.csv',index=False)

# %%
df_EDA.drop(df_EDA.columns[0],inplace=True,axis=1)

# %%
df_EDA.columns
# Out:
# Index(['Name', 'Color', 'Model', 'Ratings(*)', 'Reviews', 'MobilesSold',
#        'OfferInPerentage', 'DiscountedPrice', 'MaxRetailPrice', 'Sales',
#        'RAM(GB)', 'ROM(GB)', 'Display(inches)', 'Screen', 'Rear Camera',
#        'Front Camera', 'No of Rear Camera', 'No of Front Camera', 'Battery',
#        'Processor', 'Display', 'ROM', 'RAM', 'Battery(mAh)',
#        'ComapnyWiseSales'],
#       dtype='object')

# %%
df_EDA.describe()
# Out:
#         Ratings(*)    MobilesSold  OfferInPerentage  DiscountedPrice  \
# count  1245.000000    1300.000000       1300.000000      1300.000000
# mean      4.320803    9737.003846         16.613077     27469.286923
# std       0.172673   23052.007130         13.255887     30400.735923
# min       3.300000       0.000000          0.000000         0.000000
# 25%       4.200000     185.000000          5.000000     11242.000000
# 50%       4.300000    1463.000000         16.000000     16990.000000
# 75%       4.400000    8676.000000         26.000000     28805.000000
# max       4.800000  211231.000000         98.000000    184999.000000
#
#        MaxRetailPrice  Sales(₹ CR)  No of Rear Camera  No of Front Camera  \
# count     1300.000000  1300.000000        1107.000000          981.000000
# mean     31481.865277    13.350203           2.257453            0.797146
# std      33100.849791    28.279521           1.057833            0.450206
# ...

# %%
df_EDA.groupby('Name').Sales.sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Name'>

# %%
df_EDA.groupby('Model').Sales.sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Model'>

# %%
off=df_EDA['OfferInPerentage']
plt.hist(off)
# Out:
# (array([442., 327., 311., 162.,  34.,  20.,   3.,   0.,   0.,   1.]),
#  array([ 0. ,  9.8, 19.6, 29.4, 39.2, 49. , 58.8, 68.6, 78.4, 88.2, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
df_EDA['Ratings(*)'].hist()
# Out:
# <Axes: >

# %%
#bat=df_EDA['Blseattery(mAh)'].astype(float)
#df_EDA.boxplot(column=['off','sal','Ratings(*)'])

df_EDA.boxplot(by ='Screen', column =['MobilesSold'], grid = False)
# Out:
# <Axes: title={'center': 'MobilesSold'}, xlabel='Screen'>

# %%
df_EDA[['MobilesSold','MaxRetailPrice','Ratings(*)']].corr()
# Out:
#                 MobilesSold  MaxRetailPrice  Ratings(*)
# MobilesSold        1.000000       -0.193186    0.220051
# MaxRetailPrice    -0.193186        1.000000    0.442383
# Ratings(*)         0.220051        0.442383    1.000000

# %%
sns.heatmap(df_EDA[['MobilesSold','MaxRetailPrice','Ratings(*)']].corr(), cmap ='RdYlGn', linewidths = 0.30, annot = True)
# Out:
# <Axes: >

# %%
df_cat = df_EDA[['Name','Model','Screen','Processor']]

# %%
for i in df_cat:
    num= df_cat[i].value_counts()[:10]
    sns.barplot(x=num.index,y=num)
    plt.show()

# %%
cnt = df_EDA['Processor'].value_counts()
cnt
# Out:
# Processor
# Snapdragon                 360
# Bionic Chip                127
# Mediatek                   103
# Exynos                      79
# Qualcomm                    52
# MediaTek                    37
# Helio                       25
# Octa Core                   21
# Helio P35                   19
# Unisoc                      18
# Snapdragon 695              16
# 7050                         9
# Dimensity 6020               9
# 6100                         8
# T612                         6
# Mediatek Dimensity 7200      5
# UMS9230                      5
# 208MHz                       4
# SC9863A                      4
# Octa-core                    4
# Mediatek Dimensity 1200      3
# quad core                    2
# Helio G85                    2
# A8 Chip  64-bit              2
# A9 64-bit                    2
# 8 Gen 1                      2
# 6 Core                       1
# A7 64-bit                    1
# Name: count, dtype: int64

# %%
result = df_EDA['Sales(₹ CR)'].sum()
result
# Out:
# 17355.264000000003

# %%
pd.pivot_table(df_EDA, index='Name',values='Sales')
# Out:
#              Sales
# Name
# APPLE    24.073474
# Mi        8.422000
# POCO     14.823047
# Redmi    20.182973
# SAMSUNG   2.765807
# Xiaomi    2.079750
# realme    7.664502
# vivo     24.131295

# %%
pd.pivot_table(df_EDA, index=['Name','Model'],values='Sales')
# Out:
#                              Sales
# Name  Model
# APPLE iPhone 11          45.151500
#       iPhone 11 Pro Max   0.957000
#       iPhone 12          68.593143
#       iPhone 12 mini     52.371000
#       iPhone 13          79.585824
# ...                            ...
# vivo  Y75 5G              3.173333
#       Y81                51.260000
#       Y91i                0.000000
#       Z1x                 0.000000
#       y15s                5.060000
#
# [363 rows x 1 columns]

# %%
df2 = df_EDA.groupby(['Name']).agg({'Sales':'sum'})
plt.scatter(df2.index, df2['Sales'])

# %%
df2 = df_EDA.groupby(['Model']).agg({'Sales':'sum'})
plt.scatter(df2.index, df2['Sales'])
